# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import joblib

T1=pd.read_csv("./gdrive/MyDrive/Sample.csv",encoding='euc-kr')
T2=T1.iloc[:,1:8]

loaded_model = joblib.load('./gdrive/MyDrive/Predict_Delirium_after_knee_arthroplasty.pkl')
T=[loaded_model.predict_proba(T2)[i][1]>0.085 for i in range(len(T2))]

T
# Out:
# [True, True, False]
